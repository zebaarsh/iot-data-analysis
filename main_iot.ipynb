# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
data = pd.read_csv("/Users/rosy/Desktop/data.txt", sep = ' ',header = None, names = ['sdate', 'stime','epoch','moteid','temp','humidity','light','voltage'],index_col=False, dtype='unicode')
data.head()
# Out:
#         sdate            stime epoch moteid     temp  humidity  light  voltage
# 0  2004-03-31  03:38:15.757551     2      1  122.153  -3.91901  11.04  2.03397
# 1  2004-02-28   00:59:16.02785  3Ish      1  19.9884   37.0933  45.08  2.69964
# 2  2004-02-28   01:03:16.33393    11      1  19.3024   38.4629  45.08  2.68742
# 3  2004-02-28  01:06:16.013453    17      1  19.1652   38.8039  45.08  2.68742
# 4  2004-02-28  01:06:46.778088    18      1   19.175   38.8379  45.08  2.69964

# %%
data.tail()
# Out:
#               sdate            stime  epoch moteid temp humidity light voltage
# 2313677  2004-04-02  01:14:54.164318  61274    NaN  NaN      NaN   NaN     NaN
# 2313678  2004-04-02  01:17:53.670524  61275    NaN  NaN      NaN   NaN     NaN
# 2313679  2004-04-02  01:20:52.807972  61276    NaN  NaN      NaN   NaN     NaN
# 2313680  2004-04-02  01:26:53.950342  61278    NaN  NaN      NaN   NaN     NaN
# 2313681  2004-04-02  01:35:53.897412  61280    NaN  NaN      NaN   NaN     NaN

# %%
#data.columns = ['sdate', 'stime','epoch','moteid','temp','humidity','light','voltage']
data.to_csv('inteldata.csv')
#data.head(2000).to_csv('intelshort.csv')

# %%
data.fillna(0, inplace=True)
#print(data)
data['epoch'].replace(regex=True, inplace=True, to_replace=r'[^0-9.\-]', value=r'')
data['epoch'] = data['epoch'].astype(int)
data.to_csv('intelclean.csv')

# %%
#data['date'] = '2004-02-28'
#data['time'] = '00:59:16.02785'
#data.loc[data['date' == '2004-02-28']]
#data.groupby([''])
data

#df['timestamp'] = df[['sdate', 'stime']].apply(lambda x: ' '.join(x.astype(str)), axis=1)#
# Out:
#               sdate            stime  epoch moteid     temp  humidity  light  \
# 0        2004-03-31  03:38:15.757551      2      1  122.153  -3.91901  11.04
# 1        2004-02-28   00:59:16.02785      3      1  19.9884   37.0933  45.08
# 2        2004-02-28   01:03:16.33393     11      1  19.3024   38.4629  45.08
# 3        2004-02-28  01:06:16.013453     17      1  19.1652   38.8039  45.08
# 4        2004-02-28  01:06:46.778088     18      1   19.175   38.8379  45.08
# 5        2004-02-28  01:08:45.992524     22      1  19.1456   38.9401  45.08
# 6        2004-02-28  01:09:22.323858     23      1  19.1652    38.872  45.08
# 7        2004-02-28  01:09:46.109598     24      1  19.1652   38.8039  45.08
# 8        2004-02-28    01:10:16.6789     25      1  19.1456   38.8379  45.08
# 9        2004-02-28  01:10:46.250524     26      1  19.1456    38.872  45.08
# 10       2004-02-28  01:11:46.941288     28      1  19.1456   38.9401  45.08
# 11       2004-02-28  01:12:46.251377     30      1  19.1358   38.9061  45.08
# 12       2004-02-28   01:14:16.63127     33      1  19.1162   38.8039  45.08
# 13       2004-02-28  01:14:46.569352     34      1  19.1162    38.872  45.08
# 14       2004-02-28  01:15:16.649556     35      1  19.1064   39.0082  45.08
# 2313680  2004-04-02  01:26:53.950342  61278      0        0         0      0
# 2313681  2004-04-02  01:35:53.897412  61280      0        0         0      0
#
#          voltage
# 0        2.03397
# 1        2.69964
# 2        2.68742
# 3        2.68742
# 4        2.69964
# 5        2.68742
# 6        2.68742
# 7        2.68742
# 8        2.69964
# 9        2.68742
# 10       2.69964
# 11       2.68742
# 12       2.69964
# 13       2.69964
# 14       2.69964
# 15       2.69964
# 16       2.69964
# 17       2.69964
# 18       2.69964
# 19       2.68742
# 20       2.69964
# 21       2.69964
# 22       2.69964
# 23       2.68742
# 24       2.69964
# 25       2.69964
# 26       2.68742
# 27       2.69964
# 28       2.68742
# 29       2.69964
# ...          ...
# 2313652        0
# 2313653        0
# 2313654        0
# 2313655        0
# 2313656        0
# 2313657        0
# 2313658        0
# 2313659        0
# 2313660        0
# 2313661        0
# 2313662        0
# 2313663        0
# 2313664        0
# 2313665        0
# 2313666        0
# 2313667        0
# 2313668        0
# 2313669        0
# 2313670        0
# 2313671        0
# 2313672        0
# 2313673        0
# 2313674        0
# 2313675        0
# 2313676        0
# 2313677        0
# 2313678        0
# 2313679        0
# 2313680        0
# 2313681        0
#
# [2313682 rows x 8 columns]

# %%
df = data
df[['epoch', 'moteid','temp','humidity','light','voltage']] = df[['epoch', 'moteid','temp','humidity','light','voltage']].astype(float)
#df
df.describe()
# Out:
#               epoch        moteid          temp      humidity         light  \
# count  2.313682e+06  2.313682e+06  2.313682e+06  2.313682e+06  2.313682e+06
# mean   3.303993e+04  2.853763e+01  3.919173e+01  3.389492e+01  3.906884e+02
# std    1.836852e+04  5.062016e+01  3.741994e+01  1.733108e+01  5.344443e+02
# min    0.000000e+00  0.000000e+00 -3.840000e+01 -8.983130e+03  0.000000e+00
# 25%    1.757200e+04  1.700000e+01  2.040980e+01  3.187760e+01  1.840000e+01
# 50%    3.332700e+04  2.900000e+01  2.243840e+01  3.928030e+01  1.435200e+02
# 75%    4.778900e+04  4.100000e+01  2.701500e+01  4.358550e+01  5.078400e+02
# max    6.553500e+04  6.540700e+04  3.855680e+02  1.375120e+02  1.847360e+03
#
#             voltage
# count  2.313682e+06
# mean   2.491985e+00
# std    1.834440e-01
# min    0.000000e+00
# 25%    2.385220e+00
# 50%    2.527320e+00
# 75%    2.627960e+00
# max    1.856000e+01

# %%
data['timestamp'] = data[['sdate', 'stime']].apply(lambda x: ' '.join(x.astype(str)), axis=1)

# %%
df1= data
#df_1 = data
del df1['sdate']
del df1['stime']
df1
# Out:
#            epoch  moteid      temp  humidity  light  voltage  \
# 0            2.0     1.0  122.1530  -3.91901  11.04  2.03397
# 1            3.0     1.0   19.9884  37.09330  45.08  2.69964
# 2           11.0     1.0   19.3024  38.46290  45.08  2.68742
# 3           17.0     1.0   19.1652  38.80390  45.08  2.68742
# 4           18.0     1.0   19.1750  38.83790  45.08  2.69964
# 5           22.0     1.0   19.1456  38.94010  45.08  2.68742
# 6           23.0     1.0   19.1652  38.87200  45.08  2.68742
# 26       2004-02-28 01:26:16.656972
# 27       2004-02-28 01:26:46.463293
# 28       2004-02-28 01:28:46.483577
# 29       2004-02-28 01:29:46.102532
# ...                             ...
# 2313652  2004-04-01 23:06:18.936991
# 2313653   2004-04-01 23:17:53.33442
# 2313654   2004-04-01 23:20:53.26068
# 2313655  2004-04-01 23:23:53.046671
# 2313656  2004-04-01 23:35:53.484033
# 2313657  2004-04-01 23:38:51.026354
# 2313658  2004-04-01 23:41:51.102528
# 2313659  2004-04-01 23:44:51.351393
# 2313660  2004-04-01 23:47:53.088203
# 2313661  2004-04-01 23:56:55.955802
# 2313662  2004-04-01 23:59:52.062248
# 2313663  2004-04-02 00:02:53.403263
# 2313664  2004-04-02 00:05:53.442814
# 2313665  2004-04-02 00:11:53.478397
# 2313666  2004-04-02 00:20:53.634899
# 2313667  2004-04-02 00:29:53.263446
# 2313668  2004-04-02 00:38:53.781796
# 2313669  2004-04-02 00:50:52.464265
# 2313670  2004-04-02 00:53:52.418969
# 2313671  2004-04-02 00:56:53.359735
# 2313672  2004-04-02 00:59:53.886525
# 2313673   2004-04-02 01:02:52.43893
# 2313674   2004-04-02 01:05:53.55726
# 2313675  2004-04-02 01:08:54.053265
# 2313676  2004-04-02 01:11:53.607384
# 2313677  2004-04-02 01:14:54.164318
# 2313678  2004-04-02 01:17:53.670524
# 2313679  2004-04-02 01:20:52.807972
# 2313680  2004-04-02 01:26:53.950342
# 2313681  2004-04-02 01:35:53.897412
#
# [2313682 rows x 7 columns]

# %%
df1.timestamp = pd.to_datetime(df1.timestamp)
df1.set_index('timestamp', inplace=True)
#df1.head()
df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2313682 entries, 2004-03-31 03:38:15.757551 to 2004-04-02 01:35:53.897412
# Data columns (total 6 columns):
# epoch       float64
# moteid      float64
# temp        float64
# humidity    float64
# light       float64
# voltage     float64
# dtypes: float64(6)
# memory usage: 123.6 MB
#                             epoch  moteid      temp  humidity  light  voltage
# timestamp
# 2004-03-31 03:38:15.757551    2.0     1.0  122.1530  -3.91901  11.04  2.03397
# 2004-02-28 00:59:16.027850    3.0     1.0   19.9884  37.09330  45.08  2.69964
# 2004-02-28 01:03:16.333930   11.0     1.0   19.3024  38.46290  45.08  2.68742
# 2004-02-28 01:06:16.013453   17.0     1.0   19.1652  38.80390  45.08  2.68742
# 2004-02-28 01:06:46.778088   18.0     1.0   19.1750  38.83790  45.08  2.69964

# %%
df1[['moteid','temp','humidity','light','voltage']] = df1[['moteid','temp','humidity','light','voltage']].apply(pd.to_numeric)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2313682 entries, 2004-03-31 03:38:15.757551 to 2004-04-02 01:35:53.897412
# Data columns (total 6 columns):
# epoch       float64
# moteid      float64
# temp        float64
# humidity    float64
# light       float64
# voltage     float64
# dtypes: float64(6)
# memory usage: 123.6 MB

# %%
grouped_data = df1.groupby(['moteid'])
grouped_data['temp'].describe()
# Out:
#            count        mean        std       min        25%       50%  \
# moteid
# 0.0        526.0    0.000000   0.000000    0.0000    0.00000    0.0000
# 1.0      43047.0   35.882437  33.655123   17.1954   20.76260   22.1444
# 17.0      2.651430
# 18.0      2.560000
# 19.0      2.736960
# 20.0      3.159150
# 21.0      2.828190
# 22.0      2.801510
# 23.0      2.775330
# 24.0      2.828190
# 25.0      2.814790
# 26.0      2.788360
# 27.0      2.775330
# 28.0      2.911370
# 29.0      2.775330
# ...            ...
# 32.0     18.560000
# 33.0      2.775330
# 34.0      2.762420
# 35.0      2.699640
# 36.0      2.762420
# 37.0      2.775330
# 38.0      2.724400
# 39.0      2.762420
# 40.0      2.775330
# 41.0      2.775330
# 42.0      2.788360
# 43.0      2.762420
# 44.0      2.762420
# 45.0      2.762420
# 46.0      2.593540
# 47.0      2.762420
# 48.0      2.762420
# 49.0      2.736960
# 50.0      2.749630
# 51.0      2.749630
# 52.0      2.724400
# 53.0      2.736960
# 54.0      2.724400
# 55.0      3.125890
# 56.0      3.142430
# 57.0      3.193120
# 58.0      3.125890
# 6485.0    0.393324
# 33117.0   0.144859
# 65407.0   0.013056
#
# [62 rows x 8 columns]

# %%
df2= df1.groupby(['moteid']).corr()
df2.fillna(0, inplace=True)
df2
# Out:
#                      epoch  humidity     light      temp   voltage
# moteid
# 0.0     epoch     1.000000  0.000000  0.000000  0.000000  0.000000
#         humidity  0.000000  0.000000  0.000000  0.000000  0.000000
#         light     0.000000  0.000000  0.000000  0.000000  0.000000
#         temp      0.000000  0.000000  0.000000  0.000000  0.000000
#         voltage   0.000000  0.000000  0.000000  0.000000  0.000000
# 1.0     epoch     1.000000 -0.195395  0.014605  0.315767 -0.726957
#         humidity -0.195395  1.000000 -0.109155 -0.801979  0.537037
#         light     0.014605 -0.109155  1.000000  0.016722  0.081781
#         temp      0.315767 -0.801979  0.016722  1.000000 -0.801028
#         voltage  -0.726957  0.537037  0.081781 -0.801028  1.000000
# 2.0     epoch     1.000000 -0.159105  0.052825  0.233844 -0.657719
#         humidity -0.159105  1.000000 -0.095224 -0.752763  0.596092
#         light     0.052825 -0.095224  1.000000  0.055741  0.000358
#         temp      0.233844 -0.752763  0.055741  1.000000 -0.803202
#         voltage  -0.657719  0.596092  0.000358 -0.803202  1.000000
# 3.0     epoch     1.000000 -0.166390  0.016836  0.287500 -0.713247
#         humidity -0.166390  1.000000 -0.114200 -0.908007  0.525637
#         light     0.016836 -0.114200  1.000000  0.037717  0.058113
#         temp      0.287500 -0.908007  0.037717  1.000000 -0.729883
#         voltage  -0.713247  0.525637  0.058113 -0.729883  1.000000
# 4.0     epoch     1.000000 -0.230276 -0.018352  0.323877 -0.709500
#         humidity -0.230276  1.000000 -0.023703 -0.940304  0.783139
#         light    -0.018352 -0.023703  1.000000 -0.014815  0.104677
#         temp      0.323877 -0.940304 -0.014815  1.000000 -0.870225
#         voltage  -0.709500  0.783139  0.104677 -0.870225  1.000000
# 5.0     epoch     1.000000  0.000000  0.000000  0.000000 -0.954981
#         humidity  0.000000  0.000000  0.000000  0.000000  0.000000
#         light     0.000000  0.000000  0.000000  0.000000  0.000000
#         temp      0.000000  0.000000  0.000000  0.000000  0.000000
#         voltage  -0.954981  0.000000  0.000000  0.000000  1.000000
# ...                    ...       ...       ...       ...       ...
# 56.0    epoch     1.000000  0.123038  0.056795 -0.195408 -0.067413
#         humidity  0.123038  1.000000  0.192363 -0.743297  0.468425
#         light     0.056795  0.192363  1.000000 -0.033801  0.357814
#         temp     -0.195408 -0.743297 -0.033801  1.000000  0.101073
#         voltage  -0.067413  0.468425  0.357814  0.101073  1.000000
# 57.0    epoch     1.000000 -1.000000  0.000000  0.000000 -0.995677
#         humidity -1.000000  1.000000  0.000000  0.000000  0.995735
#         light     0.000000  0.000000  0.000000  0.000000  0.000000
#         temp      0.000000  0.000000  0.000000  0.000000  0.000000
#         voltage  -0.995677  0.995735  0.000000  0.000000  1.000000
# 58.0    epoch     1.000000  0.169369  0.103942 -0.334009  0.216494
#         humidity  0.169369  1.000000 -0.257984 -0.660601  0.640830
#         light     0.103942 -0.257984  1.000000  0.573405  0.244811
#         temp     -0.334009 -0.660601  0.573405  1.000000 -0.059959
#         voltage   0.216494  0.640830  0.244811 -0.059959  1.000000
# 6485.0  epoch     0.000000  0.000000  0.000000  0.000000  0.000000
#         humidity  0.000000  0.000000  0.000000  0.000000  0.000000
#         light     0.000000  0.000000  0.000000  0.000000  0.000000
#         temp      0.000000  0.000000  0.000000  0.000000  0.000000
#         voltage   0.000000  0.000000  0.000000  0.000000  0.000000
# 33117.0 epoch     0.000000  0.000000  0.000000  0.000000  0.000000
#         humidity  0.000000  0.000000  0.000000  0.000000  0.000000
#         light     0.000000  0.000000  0.000000  0.000000  0.000000
#         temp      0.000000  0.000000  0.000000  0.000000  0.000000
#         voltage   0.000000  0.000000  0.000000  0.000000  0.000000
# 65407.0 epoch     0.000000  0.000000  0.000000  0.000000  0.000000
#         humidity  0.000000  0.000000  0.000000  0.000000  0.000000
#         light     0.000000  0.000000  0.000000  0.000000  0.000000
#         temp      0.000000  0.000000  0.000000  0.000000  0.000000
#         voltage   0.000000  0.000000  0.000000  0.000000  0.000000
#
# [310 rows x 5 columns]

# %% [markdown]
# ### Variation in humidity, temp, light, voltage with epoch

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(60,20))

for xcol, ax in zip(['humidity', 'temp', 'light','voltage'], axes):
    df.plot(kind='scatter', x='epoch', y=xcol, ax=ax, alpha=1, color='r')

# %% [markdown]
# ### Variation in humidity, light, voltage with temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(60,20))

for xcol, ax in zip(['humidity', 'light','voltage'], axes):
    df.plot(kind='scatter', x='temp', y=xcol, ax=ax, alpha=1, color='b')

# %% [markdown]
# ### Variation in  temp, light, voltage with humidity

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(60,20))

for xcol, ax in zip(['temp', 'light','voltage'], axes):
    df.plot(kind='scatter', x='humidity', y=xcol, ax=ax, alpha=1, color='y')

# %% [markdown]
# ### Variation in temp, humidity, voltage with light

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(60,20))

for xcol, ax in zip(['temp', 'humidity','voltage'], axes):
    df.plot(kind='scatter', x='light', y=xcol, ax=ax, alpha=1, color='g')

# %% [markdown]
# ### Variation in humidity, temp, light with voltage

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(60,20))

for xcol, ax in zip(['temp', 'light','humidity'], axes):
    df.plot(kind='scatter', x='voltage', y=xcol, ax=ax, alpha=1, color='r')

# %% [markdown]
# ### Variation in temperature over time(averaged per hour)

# %%
df1.index
index_hour = df1.index.hour
df1_by_hour =df1['temp'].groupby(index_hour).mean()
df1_by_hour.plot()
plt.show()

# %%
ax = df1.plot(colormap='Dark2', figsize=(14, 7))

ax.set_xlabel('Date')

ax.set_ylabel('Variation with time')

df_summary = df1.describe()

# Specify values of cells in the table
ax.table(cellText=df_summary.values, 
          # Specify width of the table
          colWidths=[0.3]*len(df.columns), 
          # Specify row labels
          rowLabels=df_summary.index, 
          # Specify column labels
          colLabels=df_summary.columns, 
          # Specify location of the table
          loc='top') 

plt.show()

# %% [markdown]
# ### Plot of variation in epoch, moteid, temp, humidity, light and voltage against timestamp(in the given order)

# %%
df1.plot(subplots=True,
                linewidth=0.5,
                layout=(2, 4),
                figsize=(40, 20),
                sharex=False,
                sharey=False)

plt.show()

# %% [markdown]
# ## Correlation between multivariate time series using pearson and spearman method

# %%
corr_mat_p = df1.corr(method='pearson')
print('************correlation matrix using pearson*************')
corr_mat_p
# Out:
# ************correlation matrix using pearson*************
#              epoch    moteid      temp  humidity     light   voltage
# epoch     1.000000  0.006596  0.340746 -0.221278  0.041511 -0.654189
# moteid    0.006596  1.000000 -0.014062  0.023541  0.029538  0.001789
# temp      0.340746 -0.014062  1.000000 -0.707251  0.021948 -0.737583
# humidity -0.221278  0.023541 -0.707251  1.000000 -0.095084  0.507445
# light     0.041511  0.029538  0.021948 -0.095084  1.000000  0.055835
# voltage  -0.654189  0.001789 -0.737583  0.507445  0.055835  1.000000

# %%
corr_mat_sp = df1.corr(method='spearman')
print('************correlation matrix using pearson*************')
corr_mat_sp
# Out:
# ************correlation matrix using pearson*************
#              epoch    moteid      temp  humidity     light   voltage
# epoch     1.000000  0.024653  0.341834 -0.074186  0.009739 -0.756496
# moteid    0.024653  1.000000 -0.066005  0.101091  0.061005  0.022497
# temp      0.341834 -0.066005  1.000000 -0.647976  0.318111 -0.374683
# humidity -0.074186  0.101091 -0.647976  1.000000 -0.253994  0.085385
# light     0.009739  0.061005  0.318111 -0.253994  1.000000  0.089489
# voltage  -0.756496  0.022497 -0.374683  0.085385  0.089489  1.000000

# %% [markdown]
# ### The following heatmap has the similar time series placed together

# %%
import seaborn as sns
sns.clustermap(corr_mat_p)

# %% [markdown]
# # Resampling time interval: per 31 seconds to per hour

# %%
#find the variation in data per hour 


df1.index = df1.index.floor('1H')
df1.to_csv('intelhour.csv')
# df_time_mote= df1.groupby(['timestamp'])
# df_time_mote

# %% [markdown]
# # Variation in temperature readings over time for moteid's: 2 and 10

# %%
from matplotlib import pyplot as plt 
d_m2 = data.loc[data['moteid'] == 2.0]
d_m10 = data.loc[data['moteid'] == 10.0]

fig2 = plt.figure(figsize = (10,5))
d_m2['temp'].plot(label='temperature for moteid=2.0')
d_m10['temp'].plot(label='temperature for moteid=10.0')
fig2.suptitle('Variation in temperature over time for moteid= 2.0 and 10.0', fontsize=10)
plt.xlabel('timestamp', fontsize=10)
plt.ylabel('temperature', fontsize=10)
plt.legend()

# %% [markdown]
# # Variation in light readings over time for moteid's: 2 and 10

# %%
from matplotlib import pyplot as plt 
d_m2 = data.loc[data['moteid'] == 2.0]
d_m10 = data.loc[data['moteid'] == 10.0]

fig2 = plt.figure(figsize = (10,5))
d_m2['light'].plot(label='light for moteid=2.0')
d_m10['light'].plot(label='light for moteid=10.0')
fig2.suptitle('Variation in light over time for moteid= 2.0 and 10.0', fontsize=10)
plt.xlabel('timestamp', fontsize=10)
plt.ylabel('light', fontsize=10)
plt.legend()

# %% [markdown]
# # Anomaly Detection using moving average method

# %% [markdown]
# ### For moteid:10 and window size: 20, we calculate the mean and standard deviation of the data.If the next entry in the dataframe lies between mean(+-)sd*2, it is considered normal else it is considered an anamoly

# %%
from itertools import count
import matplotlib.pyplot as plt
from numpy import linspace, loadtxt, ones, convolve
import numpy as np
import pandas as pd
import collections
from random import randint
from matplotlib import style
# %matplotlib inline
def mov_average(data, window_size):

    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(data, window, 'same')

# %%
def find_anomalies(y, window_size, sigma=1.0):
    avg = mov_average(y, window_size).tolist()
    residual = y - avg
    std = np.std(residual)
    return {'standard_deviation': round(std, 3),
            'anomalies_dict': collections.OrderedDict([(index, y_i) for index, y_i, avg_i in zip(count(), y, avg)
              if (y_i > avg_i + (sigma*std)) | (y_i < avg_i - (sigma*std))])}

# %%
def plot_results(x, y, window_size, sigma_value=1,
                 text_xlabel="X Axis", text_ylabel="Y Axis", applying_rolling_std=False):
   
    plt.figure(figsize=(15, 8))
    plt.plot(x, y, "k.")
    y_av = moving_average(y, window_size)
    plt.plot(x, y_av, color='green')
    plt.xlim(0, 40000)
    plt.xlabel(text_xlabel)
    plt.ylabel(text_ylabel)
    events = {}
    events = find_anomalies(y, window_size=window_size, sigma=sigma_value)
    

    x_anom = np.fromiter(events['anomalies_dict'].keys(), dtype=int, count=len(events['anomalies_dict']))
    y_anom = np.fromiter(events['anomalies_dict'].values(), dtype=float,count=len(events['anomalies_dict']))
    plt.plot(x_anom, y_anom, "r*")
    print(x_anom)
    plt.grid(True)
    plt.show()

# %%
x = d_m10['epoch']
Y = d_m10['temp']
plot_results(x, y=Y, window_size=50, text_xlabel="Date", sigma_value=3,text_ylabel="temperature")
# Out:
# [23743 23751 23761 23999 24206 24302 24303 24324 24350 25415 26094 26101
#  26325 26336 26371 26422 26437 26549 26551 26581 26588 26622 26624 26636
#  26713 26723 29505 29506 29507 36012 36017 40733 40748 40775 40779 40787
#  40840 40841 40848 40982 41115 41201]

# %% [markdown]
# ### Note: Red points represent anomalies in temperature for moteid= 10

# %% [markdown]
# ### Future work: In similar fashion, we can calculate anamolies in the humidity, light and voltage readings for different moteids. Also, using LSTM or RNN, we can predict future temperature,humidity,light and voltage readings based on the given time series data.
